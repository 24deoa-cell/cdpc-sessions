# %% [markdown]
# <a href="https://colab.research.google.com/github/24deoa-cell/cdpc-sessions/blob/main/AD_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ls=[1,2,3]
print(type(ls))
print(ls)
# Out:
# <class 'list'>
# [1, 2, 3]

# %%
ls=[11,22,33,44,55,66,77,88,99]
print(ls[0])
print(ls[5])
print(ls[-2])
print(ls[4:8])
# Out:
# 11
# 66
# 88
# [55, 66, 77, 88]

# %%
n1 = int(input("Enter first number: "))
n2 = int(input("Enter second number: "))
n3 = int(input("Enter third number: "))
n4 = int(input("Enter fourth number: "))

max =n1
if max<n2:
  max = n2
if max<n3:
  max = n3
if max<n4:
  max = n4
print(max)
# Out:
# Enter first number: 5
# Enter second number: 6
# Enter third number: 3
# Enter fourth number: 9
# 9

# %%
n1 = int(input("Enter first number: "))
n2 = int(input("Enter second number: "))
n3 = int(input("Enter third number: "))
n4 = int(input("Enter fourth number: "))

min =n1
if min>n2:
  min = n2
if min>n3:
  min = n3
if min>n4:
  min = n4
print(min)
# Out:
# Enter first number: 9
# Enter second number: 6
# Enter third number: 8
# Enter fourth number: 3
# 3
